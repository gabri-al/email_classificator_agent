# %% [markdown]
# # LangGraph Agent in Memory
# Defining the agent's graph (state, nodes, edges) and run it in memory.

# %% [markdown]
# ## Env & Variables
# Running package install and defining global variables from a separate Notebook.

# %%
# %run ./00_Environment_and_variables

# %%
# %run ./02_Prompts_Definition
